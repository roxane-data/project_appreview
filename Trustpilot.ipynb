# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.trustpilot.com/review/velib-metropole.fr'
response = requests.get(url)
html = response.content
scraped = BeautifulSoup(html,'html.parser')

# %%
scraped
#pour voir tout ce qui a été scrapé
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script charset="UTF-8" data-domain-script="84cb5c09-05e4-488b-b71c-2fe171dca5e5" data-language="en-US" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="application/javascript">
# </script>
# <script>
#         function OptanonWrapper() {
#             var event = new CustomEvent("OptanonWrapper");
#             document.dispatchEvent(event);
#         }
#     </script>
# <link crossorigin="" href="https://googleads.g.doubleclick.net/" rel="preconnect"/>
# <link crossorigin="" href="https://www.googleadservices.com/" rel="preconnect"/>
# <link crossorigin="" href="https://www.googletagmanager.com/" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.trustpilot.net/" rel="preconnect"/>
# <link crossorigin="" href="https://api.amplitude.com/" rel="preconnect"/>
# <link crossorigin="" href="//user-images.trustpilot.com/" rel="preconnect"/>
# ...

# %%
scraped.article
# Out:
# <article class="review" data-review-domain-id="5e3b012588aab1000156b298" data-review-domain-name="velib-metropole.fr" data-review-is-reported="false" data-review-user-id="60d1f7fde46462001a8ca6d0" data-reviewmid="60d1f805f9f4870470def858" id="60d1f805f9f4870470def858">
# <script data-initial-state="review-info" type="application/json">
# ...

# %%
scraped.article.p
#ce qui est dans le texte
# Out:
# <p class="review-content__text">
# ...

# %%
link = scraped.article.p

# %%
#link['class']

# %%
#pour récupérer tous les titres, il faut trouver la classe rattachée (ici 'product pod'), utiliser la méthode findall
# et une boucle for

list = []

items = scraped.find_all('article', class_='review-card')

for item in items:
    list.append(item)
