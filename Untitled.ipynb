# %%
import pandas as pd

# for scraping app info from App Store
from itunes_app_scraper.scraper import AppStoreScraper

# for scraping app reviews from App Store
from app_store_scraper import AppStore

# for pretty printing data structures
from pprint import pprint

# for keeping track of timing
import datetime as dt
from tzlocal import get_localzone

# for building in wait times
import random
import time

# %%
from itunes_app_scraper.scraper import AppStoreScraper

scraper = AppStoreScraper()
results = scraper.get_app_ids_for_query("too-good-to-go-end-food-waste")
similar = scraper.get_similar_app_ids_for_app(results[0])

app_details = scraper.get_multiple_app_details(similar)
print(list(app_details))
# Out:
# https://itunes.apple.com/lookup?id=1008237086&country=nl&entity=software
# https://itunes.apple.com/lookup?id=977681072&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1067851965&country=nl&entity=software
# https://itunes.apple.com/lookup?id=982250066&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1301257625&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1087490062&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1510225647&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1472726261&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1113135685&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1545579060&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1531321108&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1189007291&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1484324881&country=nl&entity=software
# ...

# %%
from app_store_scraper import AppStore

# %%
my_app = AppStore(
  country='gb',        # required, 2-letter code
  app_name='too-good-to-go-end-food-waste', # required, found in app's url
  app_id=1060683933    # technically not required, found in app's url
)
# Out:
# 2021-12-02 10:49:49,724 [INFO] Base - Initialised: AppStore('gb', 'too-good-to-go-end-food-waste', 1060683933)
# 2021-12-02 10:49:49,725 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/gb/app/too-good-to-go-end-food-waste/id1060683933

# %%
## Use review method to scrape reviews from App Store
my_app.review(

)
# Print starting output for app
print('---'*20)
print('---'*20)    
print(f'***** {too-good-to-go-end-food-waste} started at {start.strftime(fmt)}')
print()

            after=dt.datetime(2020, 2, 28),
    
# Add keys to store information about which app each review is for
for rvw in reviews:
    rvw['app_name'] = app_name
    rvw['app_id'] = app_id
# Out:
# 2021-12-02 10:51:39,245 [INFO] Base - [id:1060683933] Fetched 500 reviews (500 fetched in total)
# 2021-12-02 10:51:44,463 [INFO] Base - [id:1060683933] Fetched 1020 reviews (1020 fetched in total)
# 2021-12-02 10:51:49,792 [INFO] Base - [id:1060683933] Fetched 1540 reviews (1540 fetched in total)
# 2021-12-02 10:52:13,238 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/gb/apps/1060683933/reviews?l=en-GB&offset=2000&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2021-12-02 10:52:13,242 [INFO] Base - [id:1060683933] Fetched 2000 reviews (2000 fetched in total)

# %%
# Get start time
start = dt.datetime.now(tz=get_localzone())
fmt= "%m/%d/%y - %T %p"


# Instantiate AppStore for app
app_ = AppStore(country='gb', app_name='too-good-to-go-end-food-waste', app_id=1060683933)

# Scrape reviews limit to 10,000 reviews
app_.review(how_many=10000,
            sleep=random.randint(20,25))

reviews = app_.reviews


# Print update that scraping was completed
print(f"""Done scraping. 
Scraped a total of {app_.reviews_count} reviews.\n""")

# Convert list of dicts to Pandas DataFrame and write to csv
review_df = pd.DataFrame(reviews)
#review_df.to_csv('Data/too-good-to-go-end-food-waste.csv', index=False)

# Get end time
end = dt.datetime.now(tz=get_localzone())

# Print ending output for app
print(f"""Successfully wrote too-good-to-go-end-food-waste reviews to csv
at {end.strftime(fmt)}.\n""")
print(f'Time elapsed for too-good-to-go-end-food-waste: {end-start}')
print('---'*20)
print('---'*20)
print('\n')

# Wait 5 to 10 seconds to start scraping next app
time.sleep(random.randint(5,10))
# Out:
# 2021-12-02 11:11:14,943 [INFO] Base - Initialised: AppStore('gb', 'too-good-to-go-end-food-waste', 1060683933)
# 2021-12-02 11:11:14,944 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/gb/app/too-good-to-go-end-food-waste/id1060683933
# 2021-12-02 11:11:33,751 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/gb/apps/1060683933/reviews?l=en-GB&offset=0&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2021-12-02 11:11:33,754 [INFO] Base - [id:1060683933] Fetched 0 reviews (0 fetched in total)
# Done scraping.
# Scraped a total of 0 reviews.
#
# Successfully wrote too-good-to-go-end-food-waste reviews to csv
# at 12/02/21 - 11:11:33 AM.
#
# Time elapsed for too-good-to-go-end-food-waste: 0:00:18.906437
# ------------------------------------------------------------
# ...

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:93.0) Gecko/20100101 Firefox/93.0'
}
response = requests.get('https://uk.trustpilot.com/review/toogoodtogo.com?page=2', headers=headers)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(reponse.content)
reviews = soup.find_all('article', class_='paper_paper__29o4A paper_square__XVMAC card_card__2F_07 styles_reviewCard__RMq5N')
for review in reviews:
    allUsers.append(review('aside')[0]('a')[0]('div',
                                               class_='styles_consumerDetails__2hZKg')[0]('div',
                                                                                          class_='typography_typography__23IQz typography_bodysmall__24hZa typography_weight-medium__34H_5 typography_fontstyle-normal__1_HQI styles_consumerName__1Lm3h')[0].string)      
    #convert dictionary outputted as a string to a Python Dictionary using json module
    ratingsDic = json.loads(review('script')[0].string)
    allRatings.append(ratingsDic['stars'])      
        if(not(review('aside')[0]('a')[0]('div', class_='consumer-  
      information__details')[0]('div', class_='consumer- 
      information__data')[0]('div', class_='consumer-
      information__location')) == []):         allLocations.append(review('aside')[0]('a')[0]('div', 
         class_='consumer-information__details')[0]('div', 
         class_='consumer-information__data')[0]('div',    
         class_='consumer-information__location')[0]('span')
         [0].string)
      else:         allLocations.append("")      datesDic = json.loads(review('div', class_='review-content-
      header__dates')[0]('script')[0].string)
      allDates.append(datesDic['publishedDate'])
      reviewDic = json.loads(review('script')[0].string)
      allReviewContent.append(reviewDic['reviewHeader'])
